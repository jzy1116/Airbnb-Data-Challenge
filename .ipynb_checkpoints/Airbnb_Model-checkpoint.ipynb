# %% [markdown]
# # Load Data and Packages

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-adcbba6f-1b83-41a3-b0bf-ea25b72857c3" name="files[]" multiple disabled />
#      <output id="result-adcbba6f-1b83-41a3-b0bf-ea25b72857c3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving airbnb_model.csv to airbnb_model.csv

# %%
# load packages
# %matplotlib inline
import numpy as np
import scipy
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as sm
import seaborn as sns
import sklearn as sl
from sklearn import preprocessing
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import io
import pandas as pd
df = pd.read_csv(io.BytesIO(uploaded['airbnb_model.csv']), index_col=False)

# %%
df.info()
#df.describe(percentiles = [.1, .25, .5, .75, .95])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26393 entries, 0 to 26392
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          26393 non-null  int64
#  1   guest_size          26392 non-null  float64
#  2   total_interactions  26393 non-null  int64
#  3   message_length      26393 non-null  float64
#  4   channel             26393 non-null  object
#  5   user_stage          26393 non-null  object
#  6   total_reviews       26309 non-null  float64
#  7   lead_time           26393 non-null  int64
#  8   days_of_stay        26393 non-null  int64
#  9   reply_t             14319 non-null  float64
#  10  accept_t            15247 non-null  float64
#  11  replied             26393 non-null  int64
#  12  accepted            26393 non-null  int64
#  13  booked              26393 non-null  int64
# dtypes: float64(5), int64(7), object(2)
# memory usage: 2.8+ MB

# %% [markdown]
# # Feature Preprocessing

# %%
# Drop useless column
df = df.drop(columns=['Unnamed: 0'])

# %%
# from google.colab import files

# df.to_csv('airbnb_model.csv')
# files.download('airbnb_model.csv')

# %% [markdown]
# ## Filling missing data

# %% [markdown]
# Guest size, total_reviews have nulls.
#
# Deal with nulls in reply_t and accept_t later.

# %%
# Replace guest size, total review with median 
df['total_reviews'].fillna(df['total_reviews'].median(), inplace=True)
df['guest_size'].fillna(df['guest_size'].median(), inplace=True)

# %% [markdown]
# ## Feature encoding

# %% [markdown]
# In order to see the nuances of some features' impact, I decided to create buckets for numerical variables including:
# *   Interaction
# *   Review
# *   Lead time
# *   Days of stay
# *   Message length
# *   Guest size
#
#
#
# And these bins will be used to create interactive features as well

# %%
# Binning the numerical features first

# Binning interactions
interaction = [0,10,20,30,1000]
interaction_range = ['1-10','11-20','21-30','>30']
interactions_bin = pd.cut(df['total_interactions'], bins = interaction, labels= interaction_range)
df['interactions'] = interactions_bin

# Binning reviews
review = [-1,0,10,20,30,1000]
review_range = ['0','1-10','11-20','21-30','>30']
reviews_bin = pd.cut(df['total_reviews'], bins = review, labels=review_range)
df['reviews'] = reviews_bin

# Binning lead time
lead = [-1,30,60,90,1000]
lead_range = ['1-30d','31-60d','61-90d', '>90d']
lead_bin = pd.cut(df['lead_time'], bins = lead, labels=lead_range)
df['lead_time_bin'] = lead_bin

# Binning days_of_stay
stay = [-1,5,10,15,1000]
stay_range = ['1-5d','6-10d','11-15d','>15d']
stay_bin = pd.cut(df['days_of_stay'], bins = stay, labels=stay_range)
df['days_of_stay_bin'] = stay_bin

# Binning message_length
length = [-1,150,300,450,3000]
length_range = ['0-150','151-300','301-450','>450']
length_bin = pd.cut(df['message_length'], bins = length, labels=length_range)
df['message_length_bin'] = length_bin

# Binning guest size
size = [-1,1,2,4,6,30]
size_range = ['1','2','3-4','5-6','>6']
size_bin = pd.cut(df['guest_size'], bins = size, labels=size_range)
df['guest_size_bin'] = size_bin

# %%
# One-hot-encoding each bin

# Interactions
df['1-10_interactions'] = np.where(df['interactions'] == '1-10', 1, 0)
df['11-20_interactions'] = np.where(df['interactions'] == '11-20', 1, 0)
df['21-30_interactions'] = np.where(df['interactions'] == '21-30', 1, 0)
df['>30_interactions'] = np.where(df['interactions'] == '>30', 1, 0)

# Reviews
df['0_reviews'] = np.where(df['reviews'] == '0', 1, 0)
df['1-10_reviews'] = np.where(df['reviews'] == '1-10', 1, 0)
df['11-20_reviews'] = np.where(df['reviews'] == '11-20', 1, 0)
df['21-30_reviews'] = np.where(df['reviews'] == '21-30', 1, 0)
df['>30_reviews'] = np.where(df['reviews'] == '>30', 1, 0)

# Lead time
df['1-30d_lead_time'] = np.where(df['lead_time_bin'] == '1-30d', 1, 0)
df['31-60d_lead_time'] = np.where(df['lead_time_bin'] == '31-60d', 1, 0)
df['61-90d_lead_time'] = np.where(df['lead_time_bin'] == '61-90d', 1, 0)
df['>90d_lead_time'] = np.where(df['lead_time_bin'] == '>90d', 1, 0)

# Days of stay
df['1-5d_stay'] = np.where(df['days_of_stay_bin'] == '1-5d', 1, 0)
df['6-10d_stay'] = np.where(df['days_of_stay_bin'] == '6-10d', 1, 0)
df['11-15d_stay'] = np.where(df['days_of_stay_bin'] == '11-15d', 1, 0)
df['>15d_stay'] = np.where(df['days_of_stay_bin'] == '>15d', 1, 0)

# Message length
df['0-150_char_message'] = np.where(df['message_length_bin'] == '0-150', 1, 0)
df['151-300_char_message'] = np.where(df['message_length_bin'] == '151-300', 1, 0)
df['301-450_char_message'] = np.where(df['message_length_bin'] == '301-450', 1, 0)
df['>450_char_message'] = np.where(df['message_length_bin'] == '>450', 1, 0)

# Guest size
size = [-1,1,2,4,6,30]
size_range = ['1','2','3-4','5-6','>6']
df['1_guest'] = np.where(df['guest_size_bin'] == '1', 1, 0)
df['2_guests'] = np.where(df['guest_size_bin'] == '2', 1, 0)
df['3-4_guests'] = np.where(df['guest_size_bin'] == '3-4', 1, 0)
df['5-6_guests'] = np.where(df['guest_size_bin'] == '5-6', 1, 0)
df['>6_guests'] = np.where(df['guest_size_bin'] == '>6', 1, 0)

# %%
# Categorical features 
df['contact_me'] = np.where(df['channel'] == 'contact_me', 1, 0)
df['past_booker'] = np.where(df['user_stage'] == 'past_booker', 1, 0)

# %%
# Drop original numerical/categorical features 
df = df.drop(columns=['total_interactions', 'total_reviews', 'lead_time', 'days_of_stay', 'message_length', 'guest_size', 'interactions', 'reviews', 'lead_time_bin',	'days_of_stay_bin',	'message_length_bin', 'guest_size_bin', 'user_stage'])

# %% [markdown]
# ## Interaction features

# %%
interactions = ['1-10_interactions', '11-20_interactions', '21-30_interactions', '>30_interactions']
reviews = ['0_reviews', '1-10_reviews', '11-20_reviews', '21-30_reviews', '>30_reviews']
lead_times = ['1-30d_lead_time', '31-60d_lead_time', '61-90d_lead_time', '>90d_lead_time']
stays = ['1-5d_stay', '6-10d_stay', '11-15d_stay', '>15d_stay']
message_lengths = ['0-150_char_message', '151-300_char_message', '301-450_char_message', '>450_char_message']
guest_sizes = ['1_guest', '2_guests', '3-4_guests', '5-6_guests', '>6_guests']

# Interaction * message length
for i in interactions:
  for j in message_lengths:
    df[i+'*'+j] = df[i] * df[j]

# Interaction * lead time
for i in interactions:
  for j in lead_times:
    df[i+'*'+j] = df[i] * df[j]

# Interaction * days of stay
for i in interactions:
  for j in stays:
    df[i+'*'+j] = df[i] * df[j]

# User stage + interactions
for i in interactions:
    df['past_booker'+'*'+i] = df['past_booker'] * df[i]

# Channel * user stage
df['contact_me*past_booker'] = df['contact_me'] * df['past_booker']

# Channel * lead_time
for i in lead_times:
  df['contact_me'+'*'+i] = df['contact_me'] * df[i]

# Channel * guest size
for i in guest_sizes:
  df['contact_me'+'*'+i] = df['contact_me'] * df[i]

# Message length * days of stay
for i in message_lengths:
  for j in stays:
    df[i+'*'+j] = df[i] * df[j]

# Message length * lead time
for i in message_lengths:
  for j in lead_times:
    df[i+'*'+j] = df[i] * df[j]

# %%
df.head(10)
# Out:
#         channel  ...  >450_char_message*>90d_lead_time
# 0       book_it  ...                                 0
# 1    contact_me  ...                                 0
# 2    contact_me  ...                                 0
# 3    contact_me  ...                                 0
# 4  instant_book  ...                                 0
# 5    contact_me  ...                                 0
# 6    contact_me  ...                                 0
# 7  instant_book  ...                                 1
# 8  instant_book  ...                                 0
# 9       book_it  ...                                 0
#
# [10 rows x 128 columns]

# %% [markdown]
# ## Feature scaling

# %%
# Scale reply_t and accept_t (MinMax scaling)
sc_scale = preprocessing.MinMaxScaler().fit(df[['reply_t', 'accept_t']])
df[['reply_t', 'accept_t']] = sc_scale.transform(df[['reply_t', 'accept_t']])

# %% [markdown]
# ## Split dataset by step

# %%
# All inquiries to predict reply, leave out Instant Book
all_inquiries = df[df['channel'] != 'instant_book'].copy()

# Rplied inquiries to predict acceptance
replied_inquiries = all_inquiries[all_inquiries['replied'] == 1].copy()

# Accepted inquiries to predict booking, leave out book it channel
accepted_inquiries = replied_inquiries[replied_inquiries['accepted'] == 1].copy() 
accepted_inquiries = accepted_inquiries[accepted_inquiries['channel'] != 'book_it']

# %%
all_inquiries.head(10)
#replied_inquiries.info()
#accepted_inquiries.info()
# Out:
#        channel  ...  >450_char_message*>90d_lead_time
# 0      book_it  ...                                 0
# 1   contact_me  ...                                 0
# 2   contact_me  ...                                 0
# 3   contact_me  ...                                 0
# 5   contact_me  ...                                 0
# 6   contact_me  ...                                 0
# 9      book_it  ...                                 0
# 10  contact_me  ...                                 0
# 11     book_it  ...                                 0
# 12     book_it  ...                                 0
#
# [10 rows x 128 columns]

# %% [markdown]
# # Model for all inquiries

# %% [markdown]
# ## Feature preprocessing for all inquiries

# %%
# Excluding all the features related to total interactions, which cannot predict reply
drop_columns = []

for c in all_inquiries.columns:
  if 'interactions' in c:
    drop_columns.append(c)

all_inquiries = all_inquiries.drop(drop_columns, axis = 1)

# %%
# Drop fake replies
all_inquiries = all_inquiries.drop(all_inquiries[all_inquiries['replied'] == 1 & (all_inquiries.reply_t.isnull())].index)

# Drop useless columns
all_inquiries = all_inquiries.drop(['channel', 'reply_t', 'accept_t'], axis = 1)

all_inquiries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16083 entries, 1 to 26390
# Data columns (total 69 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   replied                                16083 non-null  int64
#  1   accepted                               16083 non-null  int64
#  2   booked                                 16083 non-null  int64
#  3   0_reviews                              16083 non-null  int64
#  4   1-10_reviews                           16083 non-null  int64
#  5   11-20_reviews                          16083 non-null  int64
#  6   21-30_reviews                          16083 non-null  int64
#  7   >30_reviews                            16083 non-null  int64
#  8   1-30d_lead_time                        16083 non-null  int64
#  9   31-60d_lead_time                       16083 non-null  int64
#  10  61-90d_lead_time                       16083 non-null  int64
#  11  >90d_lead_time                         16083 non-null  int64
#  12  1-5d_stay                              16083 non-null  int64
#  13  6-10d_stay                             16083 non-null  int64
#  14  11-15d_stay                            16083 non-null  int64
#  15  >15d_stay                              16083 non-null  int64
#  16  0-150_char_message                     16083 non-null  int64
#  17  151-300_char_message                   16083 non-null  int64
#  18  301-450_char_message                   16083 non-null  int64
#  19  >450_char_message                      16083 non-null  int64
#  20  1_guest                                16083 non-null  int64
#  21  2_guests                               16083 non-null  int64
#  22  3-4_guests                             16083 non-null  int64
#  23  5-6_guests                             16083 non-null  int64
#  24  >6_guests                              16083 non-null  int64
#  25  contact_me                             16083 non-null  int64
#  26  past_booker                            16083 non-null  int64
#  27  contact_me*past_booker                 16083 non-null  int64
#  28  contact_me*1-30d_lead_time             16083 non-null  int64
#  29  contact_me*31-60d_lead_time            16083 non-null  int64
#  30  contact_me*61-90d_lead_time            16083 non-null  int64
#  31  contact_me*>90d_lead_time              16083 non-null  int64
#  32  contact_me*1_guest                     16083 non-null  int64
#  33  contact_me*2_guests                    16083 non-null  int64
#  34  contact_me*3-4_guests                  16083 non-null  int64
#  35  contact_me*5-6_guests                  16083 non-null  int64
#  36  contact_me*>6_guests                   16083 non-null  int64
#  37  0-150_char_message*1-5d_stay           16083 non-null  int64
#  38  0-150_char_message*6-10d_stay          16083 non-null  int64
#  39  0-150_char_message*11-15d_stay         16083 non-null  int64
#  40  0-150_char_message*>15d_stay           16083 non-null  int64
#  41  151-300_char_message*1-5d_stay         16083 non-null  int64
#  42  151-300_char_message*6-10d_stay        16083 non-null  int64
#  43  151-300_char_message*11-15d_stay       16083 non-null  int64
#  44  151-300_char_message*>15d_stay         16083 non-null  int64
#  45  301-450_char_message*1-5d_stay         16083 non-null  int64
#  46  301-450_char_message*6-10d_stay        16083 non-null  int64
#  47  301-450_char_message*11-15d_stay       16083 non-null  int64
#  48  301-450_char_message*>15d_stay         16083 non-null  int64
#  49  >450_char_message*1-5d_stay            16083 non-null  int64
#  50  >450_char_message*6-10d_stay           16083 non-null  int64
#  51  >450_char_message*11-15d_stay          16083 non-null  int64
#  52  >450_char_message*>15d_stay            16083 non-null  int64
#  53  0-150_char_message*1-30d_lead_time     16083 non-null  int64
#  54  0-150_char_message*31-60d_lead_time    16083 non-null  int64
#  55  0-150_char_message*61-90d_lead_time    16083 non-null  int64
#  56  0-150_char_message*>90d_lead_time      16083 non-null  int64
#  57  151-300_char_message*1-30d_lead_time   16083 non-null  int64
#  58  151-300_char_message*31-60d_lead_time  16083 non-null  int64
#  59  151-300_char_message*61-90d_lead_time  16083 non-null  int64
#  60  151-300_char_message*>90d_lead_time    16083 non-null  int64
#  61  301-450_char_message*1-30d_lead_time   16083 non-null  int64
#  62  301-450_char_message*31-60d_lead_time  16083 non-null  int64
#  63  301-450_char_message*61-90d_lead_time  16083 non-null  int64
#  64  301-450_char_message*>90d_lead_time    16083 non-null  int64
#  65  >450_char_message*1-30d_lead_time      16083 non-null  int64
#  66  >450_char_message*31-60d_lead_time     16083 non-null  int64
#  67  >450_char_message*61-90d_lead_time     16083 non-null  int64
#  68  >450_char_message*>90d_lead_time       16083 non-null  int64
# dtypes: int64(69)
# memory usage: 8.6 MB

# %%
# Split training and test dataset
from sklearn.model_selection import train_test_split

model_train, model_test = train_test_split(all_inquiries, test_size=0.15, random_state = 3)
model_train_x = model_train.drop(['replied', 'accepted', 'booked'], axis = 1)
model_test_x = model_test.drop(['replied', 'accepted', 'booked'], axis = 1)
model_train_y = model_train['replied']
model_test_y = model_test['replied']

# %% [markdown]
# ## Train model and find optimal hypermarameters

# %%
from sklearn.model_selection import GridSearchCV

# helper function for printing out grid search results 
def print_grid_search_metrics(gs):
    print ("Best score: %0.3f" % gs.best_score_)
    print ("Best parameters set:")
    best_parameters = gs.best_params_
    for param_name in sorted(parameters.keys()):
        print("\t%s: %r" % (param_name, best_parameters[param_name]))

# %%
#from sklearn.ensemble import RandomForestClassifier
#from sklearn.neighbors import KNeighborsClassifier 
from sklearn.linear_model import LogisticRegression

# Logistic Regression
classifier_logistic = LogisticRegression()

# Possible hyperparamter options for Logistic Regression Regularization
# Penalty is choosed from L1 or L2
# C is the lambda value(weight) for L1 and L2

# ('l1', 1) ('l1', 5), ('l1', 10) ('l2', 1) ('l2', 5), ('l2', 10)
parameters = {
    'penalty':('l1', 'l2'), 
    'C':(1, 5, 10)
}
Grid_LR = GridSearchCV(LogisticRegression(),parameters, cv=5)
Grid_LR.fit(model_train_x, model_train_y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# GridSearchCV(cv=5, error_score=nan,
#              estimator=LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                           fit_intercept=True,
#                                           intercept_scaling=1, l1_ratio=None,
#                                           max_iter=100, multi_class='auto',
#                                           n_jobs=None, penalty='l2',
#                                           random_state=None, solver='lbfgs',
#                                           tol=0.0001, verbose=0,
#                                           warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': (1, 5, 10), 'penalty': ('l1', 'l2')},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
# the best hyperparameter combination
print_grid_search_metrics(Grid_LR)
# Out:
# Best score: 0.877
# Best parameters set:
# 	C: 1
# 	penalty: 'l2'

# %%
# best model
best_LR_model = Grid_LR.best_estimator_

# %% [markdown]
# ## Model evaluation

# %% [markdown]
# ### Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# calculate accuracy, precision and recall, [[tn, fp],[]]
def cal_evaluation(classifier, cm):
    tn = cm[0][0]
    fp = cm[0][1]
    fn = cm[1][0]
    tp = cm[1][1]
    accuracy  = (tp + tn) / (tp + fp + fn + tn + 0.0)
    precision = tp / (tp + fp + 0.0)
    recall = tp / (tp + fn + 0.0)
    print (classifier)
    print ("Accuracy is: %0.3f" % accuracy)
    print ("precision is: %0.3f" % precision)
    print ("recall is: %0.3f" % recall)

# print out confusion matrices
def draw_confusion_matrices(confusion_matricies):
    class_names = ['Not','reply']
    for cm in confusion_matrices:
        classifier, cm = cm[0], cm[1]
        cal_evaluation(classifier, cm)
        fig = plt.figure()
        ax = fig.add_subplot(111)
        cax = ax.matshow(cm, interpolation='nearest',cmap=plt.get_cmap('Reds'))
        plt.title('Confusion matrix for %s' % classifier)
        fig.colorbar(cax)
        ax.set_xticklabels([''] + class_names)
        ax.set_yticklabels([''] + class_names)
        plt.xlabel('Predicted')
        plt.ylabel('True')
        plt.show()

# %%
confusion_matrix(model_test_y, best_LR_model.predict(model_test_x))
# Out:
# array([[   0,  269],
#        [   0, 2144]])

# %%
# %matplotlib inline

# Confusion matrix, accuracy, precison and recall for random forest and logistic regression
confusion_matrices = [
    ("Logistic Regression", confusion_matrix(model_test_y, best_LR_model.predict(model_test_x))),
    #("Logistic Regression", confusion_matrix(yc_test,best_LR_model.predict(Xc_test))),
]

draw_confusion_matrices(confusion_matrices)
# Out:
# Logistic Regression
# Accuracy is: 0.889
# precision is: 0.889
# recall is: 1.000

# %% [markdown]
# ### ROC & AUC

# %%
from sklearn.metrics import roc_curve
from sklearn import metrics

# Use predict_proba to get the probability results of Logistic Regression
y_pred_lr = best_LR_model.predict_proba(model_test_x)[:, 1]
fpr_lr, tpr_lr, _ = roc_curve(model_test_y, y_pred_lr)

# %%
# ROC Curve
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_lr, tpr_lr, label='LR')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve - LR Model')
plt.legend(loc='best')
plt.show()

# %%
# AUC score
metrics.auc(fpr_lr,tpr_lr)
# Out:
# 0.6559370318481941

# %% [markdown]
# ## Feature selection

# %%
# Store the coef for feature selection
res = pd.DataFrame(columns=['Feature', 'Coef'])

for k,v in sorted(zip(map(lambda x: round(x, 4), best_LR_model.fit(model_train_x, model_train_y).coef_[0]), \
                      model_train_x.columns), key=lambda k_v:(-abs(k_v[0]),k_v[1])):
    print (v + ": " + str(k))
    res = res.append({'Feature': v, 'Coef': k}, ignore_index=True)
# Out:
# 0_reviews: -0.966
# >30_reviews: 0.6405
# 21-30_reviews: 0.5459
# 1-10_reviews: -0.4155
# contact_me: 0.3457
# >450_char_message*31-60d_lead_time: -0.3353
# >450_char_message*>15d_stay: 0.272
# 151-300_char_message*31-60d_lead_time: 0.2582
# contact_me*past_booker: -0.23
# contact_me*3-4_guests: -0.221
# >450_char_message*61-90d_lead_time: 0.22
# 3-4_guests: 0.2091
# 11-20_reviews: 0.2011
# >15d_stay: 0.1936
# contact_me*1_guest: 0.1848
# 151-300_char_message*61-90d_lead_time: -0.1717
# contact_me*61-90d_lead_time: 0.1665
# >450_char_message*1-30d_lead_time: 0.1624
# >6_guests: -0.1588
# contact_me*>6_guests: 0.154
# >450_char_message*6-10d_stay: -0.1508
# 1_guest: -0.1492
# 301-450_char_message*>15d_stay: 0.1487
# 0-150_char_message*1-30d_lead_time: -0.1459
# 151-300_char_message*11-15d_stay: 0.1404
# contact_me*2_guests: 0.1383
# 0-150_char_message*>15d_stay: -0.1299
# >450_char_message*11-15d_stay: -0.1299
# contact_me*31-60d_lead_time: 0.1269
# 5-6_guests: 0.1134
# 11-15d_stay: -0.1128
# 0-150_char_message: -0.1111
# 301-450_char_message*11-15d_stay: -0.1097
# past_booker: 0.1066
# 151-300_char_message*>15d_stay: -0.0972
# contact_me*5-6_guests: 0.0896
# contact_me*1-30d_lead_time: 0.0807
# 0-150_char_message*6-10d_stay: 0.0763
# 61-90d_lead_time: 0.0731
# >90d_lead_time: -0.0669
# >450_char_message*1-5d_stay: 0.0648
# 151-300_char_message*>90d_lead_time: -0.0608
# >450_char_message: 0.0562
# 0-150_char_message*>90d_lead_time: -0.053
# 151-300_char_message*1-5d_stay: -0.0525
# 151-300_char_message*6-10d_stay: 0.0492
# 0-150_char_message*31-60d_lead_time: 0.0488
# 6-10d_stay: -0.0477
# 0-150_char_message*1-5d_stay: -0.0439
# 151-300_char_message: 0.0398
# 0-150_char_message*61-90d_lead_time: 0.0389
# 301-450_char_message*>90d_lead_time: 0.0378
# contact_me*>90d_lead_time: -0.0284
# 1-5d_stay: -0.027
# 301-450_char_message*6-10d_stay: -0.0225
# 301-450_char_message*1-30d_lead_time: -0.0219
# 301-450_char_message: 0.0212
# 301-450_char_message*31-60d_lead_time: 0.0194
# 151-300_char_message*1-30d_lead_time: 0.0141
# 301-450_char_message*61-90d_lead_time: -0.0141
# 0-150_char_message*11-15d_stay: -0.0136
# >450_char_message*>90d_lead_time: 0.0091
# 31-60d_lead_time: -0.0089
# 1-30d_lead_time: 0.0087
# 2_guests: -0.0085
# 301-450_char_message*1-5d_stay: 0.0047

# %%
from google.colab import files

res.to_csv('mod1_res.csv')
files.download('mod1_res.csv')

# %%
#interaction = res[res.Feature.str.contains('interaction', regex=False)]
#res_pos = res[res.Coef >= 0]
#res_pos.style.background_gradient(subset=['Coef'], cmap='BuGn')

# %% [markdown]
# # Model for replied inquiries

# %% [markdown]
# ## Feature preprocessing for replied inquiries

# %%
# Drop useless columns
replied_inquiries = replied_inquiries.drop(['channel', 'accept_t'], axis = 1)

# Drop fake replies
replied_inquiries = replied_inquiries.dropna() 
replied_inquiries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14129 entries, 1 to 26390
# Columns: 126 entries, reply_t to >450_char_message*>90d_lead_time
# dtypes: float64(1), int64(125)
# memory usage: 13.7 MB

# %%
# Split training and test dataset
from sklearn.model_selection import train_test_split
model_train, model_test = train_test_split(replied_inquiries, test_size=0.15, random_state = 3)
model_train_x = model_train.drop(['replied', 'accepted', 'booked'], axis = 1)
model_test_x = model_test.drop(['replied', 'accepted', 'booked'], axis = 1)
model_train_y = model_train['accepted']
model_test_y = model_test['accepted']

# %% [markdown]
# ## Train model and find optimal hypermarameters

# %%
from sklearn.model_selection import GridSearchCV

# helper function for printing out grid search results 
def print_grid_search_metrics(gs):
    print ("Best score: %0.3f" % gs.best_score_)
    print ("Best parameters set:")
    best_parameters = gs.best_params_
    for param_name in sorted(parameters.keys()):
        print("\t%s: %r" % (param_name, best_parameters[param_name]))

# %%
#from sklearn.ensemble import RandomForestClassifier
#from sklearn.neighbors import KNeighborsClassifier 
from sklearn.linear_model import LogisticRegression

# Logistic Regression
classifier_logistic = LogisticRegression()

# Possible hyperparamter options for Logistic Regression Regularization
# Penalty is choosed from L1 or L2
# C is the lambda value(weight) for L1 and L2

# ('l1', 1) ('l1', 5), ('l1', 10) ('l2', 1) ('l2', 5), ('l2', 10)
parameters = {
    'penalty':('l1', 'l2'), 
    'C':(1, 5, 10)
    #'C':np.logspace (2, 5, num=20)
}
Grid_LR = GridSearchCV(LogisticRegression(),parameters, cv=5)
Grid_LR.fit(model_train_x, model_train_y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# GridSearchCV(cv=5, error_score=nan,
#              estimator=LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                           fit_intercept=True,
#                                           intercept_scaling=1, l1_ratio=None,
#                                           max_iter=100, multi_class='auto',
#                                           n_jobs=None, penalty='l2',
#                                           random_state=None, solver='lbfgs',
#                                           tol=0.0001, verbose=0,
#                                           warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': (1, 5, 10), 'penalty': ('l1', 'l2')},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
# the best hyperparameter combination
print_grid_search_metrics(Grid_LR)
# Out:
# Best score: 0.760
# Best parameters set:
# 	C: 1
# 	penalty: 'l2'

# %%
# best model
best_LR_model = Grid_LR.best_estimator_

# %% [markdown]
# ## Model evaluation

# %% [markdown]
# ### Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# calculate accuracy, precision and recall, [[tn, fp],[]]
def cal_evaluation(classifier, cm):
    tn = cm[0][0]
    fp = cm[0][1]
    fn = cm[1][0]
    tp = cm[1][1]
    accuracy  = (tp + tn) / (tp + fp + fn + tn + 0.0)
    precision = tp / (tp + fp + 0.0)
    recall = tp / (tp + fn + 0.0)
    print (classifier)
    print ("Accuracy is: %0.3f" % accuracy)
    print ("precision is: %0.3f" % precision)
    print ("recall is: %0.3f" % recall)

# print out confusion matrices
def draw_confusion_matrices(confusion_matricies):
    class_names = ['Not','Accept']
    for cm in confusion_matrices:
        classifier, cm = cm[0], cm[1]
        cal_evaluation(classifier, cm)
        fig = plt.figure()
        ax = fig.add_subplot(111)
        cax = ax.matshow(cm, interpolation='nearest',cmap=plt.get_cmap('Reds'))
        plt.title('Confusion matrix for %s' % classifier)
        fig.colorbar(cax)
        ax.set_xticklabels([''] + class_names)
        ax.set_yticklabels([''] + class_names)
        plt.xlabel('Predicted')
        plt.ylabel('True')
        plt.show()

# %%
confusion_matrix(model_test_y, best_LR_model.predict(model_test_x))
# Out:
# array([[1252,   97],
#        [ 440,  331]])

# %%
# %matplotlib inline

# Confusion matrix, accuracy, precison and recall for random forest and logistic regression
confusion_matrices = [
    ("Logistic Regression", confusion_matrix(model_test_y, best_LR_model.predict(model_test_x))),
    #("Logistic Regression", confusion_matrix(yc_test,best_LR_model.predict(Xc_test))),
]

draw_confusion_matrices(confusion_matrices)
# Out:
# Logistic Regression
# Accuracy is: 0.747
# precision is: 0.773
# recall is: 0.429

# %% [markdown]
# ### ROC & AUC

# %%
from sklearn.metrics import roc_curve
from sklearn import metrics

# Use predict_proba to get the probability results of Logistic Regression
y_pred_lr = best_LR_model.predict_proba(model_test_x)[:, 1]
fpr_lr, tpr_lr, _ = roc_curve(model_test_y, y_pred_lr)

# %%
# ROC Curve
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_lr, tpr_lr, label='LR')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve - LR Model')
plt.legend(loc='best')
plt.show()

# %%
# AUC score
metrics.auc(fpr_lr,tpr_lr)
# Out:
# 0.7704953181441025

# %% [markdown]
# ## Feature selection

# %%
# Store the coef for feature selection
res = pd.DataFrame(columns=['Feature', 'Coef'])

for k,v in sorted(zip(map(lambda x: round(x, 4), best_LR_model.fit(model_train_x, model_train_y).coef_[0]), \
                      model_train_x.columns), key=lambda k_v:(-abs(k_v[0]),k_v[1])):
    print (v + ": " + str(k))
    res = res.append({'Feature': v, 'Coef': k}, ignore_index=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# reply_t: -2.3377
# 1-10_interactions: -1.0791
# 21-30_interactions*11-15d_stay: 0.9894
# 21-30_interactions*>450_char_message: 0.8966
# >30_interactions*>15d_stay: 0.8878
# 0_reviews: -0.8778
# 21-30_interactions: 0.799
# 1-10_interactions*>90d_lead_time: -0.742
# 21-30_interactions*>15d_stay: -0.5703
# >30_interactions: 0.5417
# 21-30_reviews: 0.5336
# contact_me*>90d_lead_time: 0.5282
# >30_reviews: 0.526
# past_booker*>30_interactions: 0.5052
# >30_interactions*>450_char_message: -0.4905
# 1-10_interactions*1-5d_stay: -0.4872
# >30_interactions*151-300_char_message: 0.4296
# 21-30_interactions*>90d_lead_time: 0.4268
# >30_interactions*11-15d_stay: -0.4239
# contact_me: 0.4056
# contact_me*1-30d_lead_time: -0.4002
# 21-30_interactions*0-150_char_message: -0.3987
# >30_interactions*301-450_char_message: 0.3699
# 1-10_interactions*301-450_char_message: -0.3642
# 1-10_interactions*151-300_char_message: -0.3522
# 11-20_interactions*>15d_stay: -0.3463
# past_booker*1-10_interactions: -0.3421
# >30_interactions*>90d_lead_time: 0.3358
# contact_me*61-90d_lead_time: 0.3351
# 11-20_reviews: 0.3264
# 11-20_interactions*1-5d_stay: 0.3238
# 1-10_interactions*6-10d_stay: -0.3144
# 31-60d_lead_time: 0.2875
# 21-30_interactions*301-450_char_message: 0.2859
# 1-10_reviews: -0.2858
# 1-10_interactions*>450_char_message: -0.2727
# 11-15d_stay: 0.2423
# 11-20_interactions*>90d_lead_time: -0.241
# >30_interactions*0-150_char_message: 0.2327
# 1_guest: 0.2304
# 21-30_interactions*61-90d_lead_time: 0.227
# 301-450_char_message*11-15d_stay: 0.2227
# >90d_lead_time: -0.2203
# past_booker: 0.2191
# 151-300_char_message*1-5d_stay: 0.2146
# 301-450_char_message: 0.2136
# >30_interactions*31-60d_lead_time: 0.2081
# 21-30_interactions*6-10d_stay: 0.2043
# 1-10_interactions*11-15d_stay: -0.1957
# 11-20_interactions*0-150_char_message: 0.1797
# past_booker*11-20_interactions: 0.1786
# contact_me*5-6_guests: 0.177
# 21-30_interactions*1-5d_stay: 0.1755
# 301-450_char_message*1-30d_lead_time: 0.1634
# >450_char_message*61-90d_lead_time: 0.1615
# 151-300_char_message*11-15d_stay: -0.1581
# 1-10_interactions*31-60d_lead_time: -0.1577
# contact_me*1_guest: -0.1534
# 1-30d_lead_time: 0.1486
# contact_me*>6_guests: 0.1445
# 5-6_guests: -0.1422
# 301-450_char_message*31-60d_lead_time: 0.1387
# contact_me*2_guests: 0.1349
# 11-20_interactions*11-15d_stay: -0.1276
# >30_interactions*61-90d_lead_time: -0.1271
# 0-150_char_message*61-90d_lead_time: -0.1261
# >30_interactions*1-30d_lead_time: 0.1249
# past_booker*21-30_interactions: -0.1226
# >450_char_message*>90d_lead_time: -0.1199
# 21-30_interactions*31-60d_lead_time: 0.1194
# 11-20_interactions*31-60d_lead_time: 0.1178
# 1-10_interactions*61-90d_lead_time: -0.1168
# 11-20_interactions*>450_char_message: -0.112
# 151-300_char_message*31-60d_lead_time: 0.1118
# 11-20_interactions*6-10d_stay: 0.111
# >15d_stay: -0.1107
# 0-150_char_message*6-10d_stay: -0.1046
# contact_me*3-4_guests: 0.1025
# 1-10_interactions*0-150_char_message: -0.09
# 0-150_char_message*11-15d_stay: 0.0898
# >450_char_message*11-15d_stay: 0.0879
# 0-150_char_message*31-60d_lead_time: 0.0866
# 151-300_char_message*6-10d_stay: 0.0838
# 1-10_interactions*>15d_stay: -0.0818
# >450_char_message*1-5d_stay: -0.0793
# 11-20_interactions*301-450_char_message: -0.0781
# 151-300_char_message*>15d_stay: -0.0765
# 0-150_char_message: -0.0763
# 301-450_char_message*1-5d_stay: -0.0731
# 151-300_char_message: 0.0638
# 1-10_interactions*1-30d_lead_time: -0.0626
# 151-300_char_message*>90d_lead_time: -0.0624
# 11-20_interactions*1-30d_lead_time: 0.0606
# contact_me*31-60d_lead_time: -0.0575
# 3-4_guests: 0.0566
# 1-5d_stay: 0.0546
# 0-150_char_message*>15d_stay: -0.054
# >450_char_message*31-60d_lead_time: -0.0496
# 301-450_char_message*61-90d_lead_time: -0.0484
# 301-450_char_message*>15d_stay: 0.0449
# 2_guests: 0.043
# >30_interactions*1-5d_stay: 0.0425
# 301-450_char_message*>90d_lead_time: -0.0401
# 11-20_interactions: -0.0391
# 0-150_char_message*1-30d_lead_time: -0.039
# contact_me*past_booker: 0.039
# >450_char_message*6-10d_stay: 0.0379
# 6-10d_stay: 0.0362
# >30_interactions*6-10d_stay: 0.0353
# >6_guests: 0.0346
# >450_char_message*1-30d_lead_time: 0.0294
# 11-20_interactions*151-300_char_message: -0.0288
# 21-30_interactions*1-30d_lead_time: 0.0257
# >450_char_message*>15d_stay: -0.025
# 11-20_interactions*61-90d_lead_time: 0.0235
# >450_char_message: 0.0214
# 151-300_char_message*61-90d_lead_time: 0.0196
# 301-450_char_message*6-10d_stay: 0.0191
# 21-30_interactions*151-300_char_message: 0.0152
# 0-150_char_message*1-5d_stay: -0.0076
# 61-90d_lead_time: 0.0066
# 151-300_char_message*1-30d_lead_time: -0.0052
# 0-150_char_message*>90d_lead_time: 0.0021

# %%
from google.colab import files

res.to_csv('mod2_res.csv')
files.download('mod2_res.csv')

# %% [markdown]
# # Model for accepted inquiries (contact me only)

# %% [markdown]
# ## Feature preprocessing for accepted inquiries

# %%
# Drop feature related to channel since only contact me channel is included in this model
drop_columns = []

for c in accepted_inquiries.columns:
  if 'contact_me' in c:
    drop_columns.append(c)

accepted_inquiries = accepted_inquiries.drop(drop_columns, axis = 1)

# Drop uselss columns
accepted_inquiries = accepted_inquiries.drop(['reply_t', 'channel'], axis = 1)
accepted_inquiries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5169 entries, 3 to 26390
# Columns: 115 entries, accept_t to >450_char_message*>90d_lead_time
# dtypes: float64(1), int64(114)
# memory usage: 4.6 MB

# %%
accepted_inquiries.head(10)
# Out:
#     accept_t  ...  >450_char_message*>90d_lead_time
# 3      0.000  ...                                 0
# 6      0.015  ...                                 0
# 33     0.006  ...                                 0
# 45     0.000  ...                                 0
# 50     0.000  ...                                 0
# 58     0.000  ...                                 0
# 62     0.000  ...                                 0
# 63     0.002  ...                                 1
# 68     0.000  ...                                 0
# 75     0.000  ...                                 0
#
# [10 rows x 115 columns]

# %%
# Split training and test dataset
from sklearn.model_selection import train_test_split

model_train, model_test = train_test_split(accepted_inquiries, test_size=0.15, random_state = 3)
model_train_x = model_train.drop(['replied', 'accepted', 'booked'], axis = 1)
model_test_x = model_test.drop(['replied', 'accepted', 'booked'], axis = 1)
model_train_y = model_train['booked']
model_test_y = model_test['booked']

# %% [markdown]
# ## Train model and find optimal hypermarameters

# %%
from sklearn.model_selection import GridSearchCV

# helper function for printing out grid search results 
def print_grid_search_metrics(gs):
    print ("Best score: %0.3f" % gs.best_score_)
    print ("Best parameters set:")
    best_parameters = gs.best_params_
    for param_name in sorted(parameters.keys()):
        print("\t%s: %r" % (param_name, best_parameters[param_name]))

# %%
#from sklearn.ensemble import RandomForestClassifier
#from sklearn.neighbors import KNeighborsClassifier 
from sklearn.linear_model import LogisticRegression

# Logistic Regression
classifier_logistic = LogisticRegression()

# Possible hyperparamter options for Logistic Regression Regularization
# Penalty is choosed from L1 or L2
# C is the lambda value(weight) for L1 and L2

# ('l1', 1) ('l1', 5), ('l1', 10) ('l2', 1) ('l2', 5), ('l2', 10)
parameters = {
    'penalty':('l1', 'l2'), 
    'C':(1, 5, 10)
}
Grid_LR = GridSearchCV(LogisticRegression(),parameters, cv=5)
Grid_LR.fit(model_train_x, model_train_y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# GridSearchCV(cv=5, error_score=nan,
#              estimator=LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                           fit_intercept=True,
#                                           intercept_scaling=1, l1_ratio=None,
#                                           max_iter=100, multi_class='auto',
#                                           n_jobs=None, penalty='l2',
#                                           random_state=None, solver='lbfgs',
#                                           tol=0.0001, verbose=0,
#                                           warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': (1, 5, 10), 'penalty': ('l1', 'l2')},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
# the best hyperparameter combination
print_grid_search_metrics(Grid_LR)
# Out:
# Best score: 0.885
# Best parameters set:
# 	C: 10
# 	penalty: 'l2'

# %%
# best model
best_LR_model = Grid_LR.best_estimator_

# %% [markdown]
# ## Model evaluation

# %% [markdown]
# ### Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# calculate accuracy, precision and recall, [[tn, fp],[]]
def cal_evaluation(classifier, cm):
    tn = cm[0][0]
    fp = cm[0][1]
    fn = cm[1][0]
    tp = cm[1][1]
    accuracy  = (tp + tn) / (tp + fp + fn + tn + 0.0)
    precision = tp / (tp + fp + 0.0)
    recall = tp / (tp + fn + 0.0)
    print (classifier)
    print ("Accuracy is: %0.3f" % accuracy)
    print ("precision is: %0.3f" % precision)
    print ("recall is: %0.3f" % recall)

# print out confusion matrices
def draw_confusion_matrices(confusion_matricies):
    class_names = ['Not','Book']
    for cm in confusion_matrices:
        classifier, cm = cm[0], cm[1]
        cal_evaluation(classifier, cm)
        fig = plt.figure()
        ax = fig.add_subplot(111)
        cax = ax.matshow(cm, interpolation='nearest',cmap=plt.get_cmap('Reds'))
        plt.title('Confusion matrix for %s' % classifier)
        fig.colorbar(cax)
        ax.set_xticklabels([''] + class_names)
        ax.set_yticklabels([''] + class_names)
        plt.xlabel('Predicted')
        plt.ylabel('True')
        plt.show()

# %%
confusion_matrix(model_test_y, best_LR_model.predict(model_test_x))
# Out:
# array([[601,  49],
#        [ 60,  66]])

# %%
# %matplotlib inline

# Confusion matrix, accuracy, precison and recall for random forest and logistic regression
confusion_matrices = [
    ("Logistic Regression", confusion_matrix(model_test_y, best_LR_model.predict(model_test_x))),
    #("Logistic Regression", confusion_matrix(yc_test,best_LR_model.predict(Xc_test))),
]

draw_confusion_matrices(confusion_matrices)
# Out:
# Logistic Regression
# Accuracy is: 0.860
# precision is: 0.574
# recall is: 0.524

# %% [markdown]
# ### ROC & AUC

# %%
from sklearn.metrics import roc_curve
from sklearn import metrics

# Use predict_proba to get the probability results of Logistic Regression
y_pred_lr = best_LR_model.predict_proba(model_test_x)[:, 1]
fpr_lr, tpr_lr, _ = roc_curve(model_test_y, y_pred_lr)

# %%
# ROC Curve
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_lr, tpr_lr, label='LR')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve - LR Model')
plt.legend(loc='best')
plt.show()

# %%
# AUC score
metrics.auc(fpr_lr,tpr_lr)
# Out:
# 0.8575030525030525

# %% [markdown]
# ## Feature selection

# %%
# Store the coef for feature selection
res = pd.DataFrame(columns=['Feature', 'Coef'])

for k,v in sorted(zip(map(lambda x: round(x, 4), best_LR_model.fit(model_train_x, model_train_y).coef_[0]), \
                      model_train_x.columns), key=lambda k_v:(-abs(k_v[0]),k_v[1])):
    print (v + ": " + str(k))
    res = res.append({'Feature': v, 'Coef': k}, ignore_index=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# accept_t: 2.8898
# 1-10_interactions: -1.8771
# >30_interactions*11-15d_stay: 1.2886
# >30_interactions: 1.1339
# 1-10_interactions*11-15d_stay: -0.7764
# >30_interactions*>90d_lead_time: 0.7495
# >30_interactions*>450_char_message: 0.7292
# >30_interactions*151-300_char_message: 0.6642
# 1-10_interactions*>90d_lead_time: -0.6308
# 21-30_interactions: 0.5978
# >15d_stay: -0.5877
# 21-30_interactions*301-450_char_message: 0.5845
# 1-10_interactions*6-10d_stay: -0.558
# 1-10_interactions*301-450_char_message: -0.5506
# past_booker: 0.5381
# 1-10_interactions*61-90d_lead_time: -0.5198
# 1-10_interactions*151-300_char_message: -0.4968
# 11-20_interactions*>15d_stay: -0.4855
# 21-30_interactions*0-150_char_message: 0.46
# 1-10_interactions*>15d_stay: -0.4547
# 21-30_interactions*>450_char_message: -0.4544
# 21-30_interactions*1-30d_lead_time: 0.4507
# 0-150_char_message*61-90d_lead_time: -0.4386
# 0_reviews: -0.4292
# 0-150_char_message: -0.4265
# 1-10_interactions*0-150_char_message: -0.4242
# 1-10_interactions*1-30d_lead_time: -0.415
# >6_guests: -0.4068
# 1-10_interactions*>450_char_message: -0.4054
# 301-450_char_message*61-90d_lead_time: 0.3974
# 11-20_interactions*1-5d_stay: 0.3825
# 21-30_interactions*>15d_stay: 0.3825
# 151-300_char_message*>15d_stay: -0.3805
# 11-20_interactions*6-10d_stay: 0.3672
# 21-30_interactions*6-10d_stay: 0.347
# past_booker*1-10_interactions: 0.3173
# 1-10_interactions*31-60d_lead_time: -0.3115
# >30_interactions*61-90d_lead_time: 0.3049
# 11-20_interactions*>450_char_message: 0.3032
# 11-20_interactions*11-15d_stay: -0.2927
# >30_interactions*0-150_char_message: -0.2849
# 151-300_char_message*11-15d_stay: 0.2592
# 151-300_char_message*1-30d_lead_time: -0.2558
# 151-300_char_message*>90d_lead_time: 0.251
# past_booker*>30_interactions: 0.233
# 301-450_char_message*>90d_lead_time: -0.218
# 0-150_char_message*1-5d_stay: -0.2143
# >450_char_message*31-60d_lead_time: 0.2128
# 11-20_interactions*61-90d_lead_time: 0.2098
# 11-20_interactions*151-300_char_message: -0.1917
# 301-450_char_message*6-10d_stay: 0.1896
# 11-20_interactions*0-150_char_message: -0.1774
# 301-450_char_message*>15d_stay: -0.1765
# >450_char_message: 0.1726
# 6-10d_stay: 0.1702
# 2_guests: 0.1668
# 1-5d_stay: 0.1603
# 21-30_interactions*31-60d_lead_time: 0.1573
# 5-6_guests: -0.1545
# 11-20_interactions*1-30d_lead_time: -0.1537
# 31-60d_lead_time: -0.1477
# 301-450_char_message*31-60d_lead_time: -0.1444
# >450_char_message*1-30d_lead_time: 0.1444
# 3-4_guests: 0.1443
# 301-450_char_message*1-5d_stay: 0.1432
# >30_interactions*1-5d_stay: -0.1388
# 21-30_interactions*11-15d_stay: -0.1362
# 0-150_char_message*>15d_stay: -0.1351
# 11-20_interactions*>90d_lead_time: -0.1329
# >450_char_message*11-15d_stay: -0.1296
# past_booker*21-30_interactions: -0.1247
# >30_interactions*1-30d_lead_time: 0.1215
# >450_char_message*1-5d_stay: 0.1163
# 151-300_char_message*1-5d_stay: 0.1151
# past_booker*11-20_interactions: 0.1124
# 151-300_char_message*31-60d_lead_time: -0.1094
# 0-150_char_message*31-60d_lead_time: -0.1066
# >450_char_message*>15d_stay: 0.1045
# >30_reviews: 0.1014
# 151-300_char_message*61-90d_lead_time: 0.0975
# 301-450_char_message: 0.0969
# >450_char_message*>90d_lead_time: -0.0941
# >450_char_message*61-90d_lead_time: -0.0905
# 0-150_char_message*6-10d_stay: -0.0903
# 1-10_interactions*1-5d_stay: -0.088
# 11-15d_stay: 0.0834
# >450_char_message*6-10d_stay: 0.0814
# 1_guest: 0.0765
# 0-150_char_message*>90d_lead_time: 0.066
# 301-450_char_message*1-30d_lead_time: 0.0621
# 21-30_reviews: 0.0603
# 301-450_char_message*11-15d_stay: -0.0593
# 1-10_reviews: 0.054
# 0-150_char_message*1-30d_lead_time: 0.0528
# 11-20_interactions*31-60d_lead_time: 0.0484
# >30_interactions*31-60d_lead_time: -0.0421
# 11-20_reviews: 0.0398
# 11-20_interactions*301-450_char_message: 0.0376
# 61-90d_lead_time: -0.0343
# >30_interactions*>15d_stay: -0.0299
# 21-30_interactions*61-90d_lead_time: -0.0293
# 11-20_interactions: -0.0283
# >30_interactions*301-450_char_message: 0.0254
# 21-30_interactions*>90d_lead_time: 0.0191
# 151-300_char_message: -0.0167
# >30_interactions*6-10d_stay: 0.0141
# 0-150_char_message*11-15d_stay: 0.0132
# 151-300_char_message*6-10d_stay: -0.0104
# 21-30_interactions*151-300_char_message: 0.0076
# >90d_lead_time: 0.0049
# 21-30_interactions*1-5d_stay: 0.0046
# 1-30d_lead_time: 0.0035

# %%
from google.colab import files

res.to_csv('mod3_res.csv')
files.download('mod3_res.csv')
